# %%
from app.logic.document_query_get_process import DocumentQueryGetProcess

# %%
process=DocumentQueryGetProcess()

# %%
request_message_dict={
  "ClientRequestId": "payslip",
  "x_client_id": "123",
  "x_client_secret":"0",
  "x_scope":"321"
}

# %%
status_code, message,queries_page_results, queries_results, queries_aggregated_results=process.run_process(request_message_dict)
# Out:
# c:\Users\ShayDondik\OneDrive - נוגמי\Desktop\document-query-get\.venv\Lib\site-packages\google\cloud\firestore_v1\base_collection.py:304: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)

# %%
print(f"agg results:{queries_aggregated_results}")

print(f"page results:{queries_page_results}")

print(f"queries results:{queries_results}")

print(f"status code:{status_code}")

print(f"message:{message}")
# Out:
# agg results:{'total_queries': 1, 'true_queries': 1, 'false_queries': 0}
# page results:[{'queryID': '0', 'page': '0', 'response': 'The first line of the document clearly states "תלוש שכר לחודש דצמבר 2024", which translates to "Payslip for December 2024". This explicit title directly identifies the document as a payslip. Additionally, the document contains sections about employee name, salary and pension department, and various notes regarding salary-related matters and forms like \'טופס 101\' (Form 101), all of which are typical elements found in or accompanying a payslip.', 'compliance': 'True', 'confidence': '1.0'}]
# queries results:[{'queryID': '0', 'compliance': 'True'}]
# status code:200
# message:OK

# %%
# curl -X POST "http://binom.dev.cgov.dgt.gcp.internal/shomer-saf/QueryGet/PollThresholdCheckResult" \
#   -H "x-client-id: 123" \
#   -H "x-scope: 321" \
#   -H "Authorization: Bearer $(gcloud auth print-access-token)" \
#   -H "Content-Type: application/json" \
#   -d '{
#     "ClientRequestId": "payslip"
#   }'
