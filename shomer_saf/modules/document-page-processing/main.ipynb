# %%
from google.auth import default
from google.auth import impersonated_credentials
from google.cloud import storage

# %%
source_credentials, _ = default(scopes=["https://www.googleapis.com/auth/cloud-platform"])

# %%
source_credentials.account
# Out:
# ''

# %%
# curl -i -X POST "http://binom.dev.cgov.dgt.gcp.internal/shomer-saf/PageProcessing/Document/PageProcessing" \
#   -H "Authorization: Bearer $(gcloud auth print-access-token)" \
#   -H "Content-Type: application/json" \
#   -d '{
#   "BucketSubPath": "ministry_folder_pdfs",
#   "DataBucketFolder": "data_bucket_folder",
#   "DnaTransactionId": "payslip.pdf",
#   "Model": "Text",
#   "PageNumber": 0,
#   "PagesBucketFolder": "pages_bucket_folder",
#   "RequestId": "REQ_123456789",
#   "Timestamp": "2025-01-15T10:30:00.000Z",
#   "Version": "app_v1.0.0"
# }'
