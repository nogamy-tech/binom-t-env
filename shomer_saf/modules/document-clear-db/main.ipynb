# %%
import base64
import json
from typing import List

from app.src.main_process import clear_db_process

# %%
clear_db_process(transactions=["shay_test_payslip"])
# Out:
# the transaction to delete that were given are: ['shay_test_payslip']
# ✅ Blob 'documents_bucket_folder/finance/shay_test_payslip2/document.pdf' deleted from bucket 'bucket_shomer_saf-d8d4de382e2de691'.
# finished clearing buckets
# c:\Users\ShayDondik\OneDrive - נוגמי\Desktop\document-clear-db\.venv\Lib\site-packages\google\cloud\firestore_v1\base_collection.py:304: UserWarning: Detected filter using positional arguments. Prefer using the 'filter' keyword argument instead.
#   return query.where(field_path, op_string, value)
# document with id :shay_test_payslip_Page_0 has been deleted
# document with id :shay_test_payslip_Page_1 has been deleted
# document with id :shay_test_payslip_Query_0 has been deleted
# document with id :shay_test_payslip_Query_1 has been deleted
# document with id :shay_test_payslip_Query_2 has been deleted
# finished clearing DB
# (200, 'SUCCESS')
