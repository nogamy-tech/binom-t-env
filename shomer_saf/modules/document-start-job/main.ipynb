# %%
from app.logic.document_start_job_process import DocumentStartJobProcess

# %%
msg = {
    "ClientRequestId": "text",
    "Document": "bmFtZSBpcyBzaGF5IGRvbmRpaw0KYWdlIGlzIDMwDQpsaXZlcyBpbiBpc3JhZWw=",
    "Queries": [
        {"model": "text", "query": "does the name of the person is danny?"},
        {"model": "text", "query": "does the age mentioned is 30?"},
        {"model": "text", "query": "is the person mentioned lives in the US?"},
    ],
    "x_client_id": "123",
    "x_client_secret": "shay",
    "x_scope": "321",
}

# %%
DocumentStartJobProcess.run_process(msg)
